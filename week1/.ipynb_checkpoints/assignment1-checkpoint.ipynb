# %%
# original poem:

#I am Cloud.
#Something soft
#I am Rose Chai Latte.
#	A piece of years-ago memories
#In the very far end 
#	Of a chunky old fridge.
#
#Today in Blank Street, 
#I’m on a discount
#	Two dollars for your dependence
#If you depend on me.

# %%
import random

# %%
identity = [
    'Galaxy',
    'Lighthouse',
    'Sushi',
    'Avalanche',
    'Balaclava',
    'Neon Lights',
    'Bag',
    'Bloodstream',
    'Butter',
    'Paradox',
    'Rain',
    'Rollercoaster',
    'Spoon',
    'Fur',
    'Hug',
    'Dandelion',
    'Child',
    'Cream',
    'Shower Head',
    'Stage'
]

# %%
adjective = [
    'nebulous',
    'loud',
    'brilliant',
    'light',
    'more',
    'proud',
    'round',
    'confusing',
    'empty',
    'romantic',
    'agonic',
    'slow',
    'Japanese',
    'close',
    'near',
    'corrupted',
    'blue',
    'reluctant',
    'competent',
    'rusty',
    'wrinkled',
    'bare',
    'fragile',
    'nostalgic',
    'catchy',
    'gloomy',
    'fast',
    'straight',
    'flat',
    'flavorful',
    'courageous',
    'risky',
    'dangerous',
    'clear',
    'clean',
    'distant'
]

# %%
somethingSentimental = [
    'handwritten letters',
    'family photo album',
    'recipe book',
    'ticket stubs',
    'music playlist',
    'mixtape',
    'hair strands',
    'songs',
    'dried flower',
    'lucky charm',
    'candle',
    'journal',
    'film camera',
    'handwritten list of favorite quotes',
    'small pebble',
    'childhood drawing',
    'touch',
    'her mind',
    'his mind',
    'favorite beach'
]

# %%
furniture_householdItems = [
    'waffle iron',
    'microwave',
    'master bedroom',
    'laundry detergent',
    'by an abandoned lake',
    'floor lamp',
    'couch',
    'kettle',
    'door',
    'mug',
    'rocking chair',
    'throw pillow',
    'dresser',
    'magazine rack',
    'French press',
    'newspaper',
    'milk carton',
    'TV',
    'keyboard',
    'piano',
    'kitchen island',
    'bathtub',
    'bedframe',
    'light switch'
]

# %%
streetName_coffeePlacesInNY = [
    'Lexington Avenue',
    'Sullivan Street',
    'Quentin Road',
    'DeKalb Avenue',
    'Nostrand Avenue',
    '59th Street',
    'Varick Street',
    '8th Street',
    'Rivington Street',
    'Spring Street',
    'Blue Bottle',
    'Devoción',
    'Abraço',
    'Hungry Ghost',
    'Delancey Street',
    'Park Avenue',
    'Astor Place',
    'Canal Street',
]

# %%
amountOfMoney = [
    'Six Canadian dollars',
    'Twenty euros',
    'Eighty-five pence',
    'Ten thousand yen',
    'Seven dollars',
    'A quarter',
    'Three quarters',
    'Fifty cents',
    'Seventy-five Swiss francs',
    'Ninety Swedish kronor',
    'Seventy Norwegian kroner',
    'Three dollars',
    'Nine bucks',
    'A dollar',
    'Ten cents',
    'Eight dollars and sixty cents',
    'Two hundred and fifty dollars',
    'Eighty-seven cents',
    'Five dollars and twenty-five cents',
]

# %%
stanza_count = 1
for i in range(stanza_count):
    print()
    print("I am " + random.choice(identity))
    print("Something " + random.choice(adjective))
    print("I am " + random.choice(identity))
    print("    A piece of " + random.choice(somethingSentimental))
    print("In the very far end ")
    print("    Of a " + random.choice(adjective) + " " +random.choice(adjective) + " " + random.choice(furniture_householdItems))
    print()
    print("Today at " + random.choice(streetName_coffeePlacesInNY))
    print("I am on a discount")
    print("    " + random.choice(amountOfMoney) + " for your dependence")
    print("If you depend on me")
# Out:
# I am Hug
# Something proud
# I am Stage
#     A piece of family photo album
# In the very far end
#     Of a fast nostalgic bathtub
#
# Today at 8th Street
# I am on a discount
#     A dollar for your dependence
# If you depend on me
